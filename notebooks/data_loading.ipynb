# %%
import pandas as pd

import os.path as op
import sys

sys.path.append(op.abspath('../code'))

import data_loaders as dload

# %%
path_to_neuron = '/Users/AlexCionca/Documents/BrainHack-2023/Piriform_neurons/data/brain hack xls/22072c4 - Copy.xls'

my_dendrite_df = dload.genenerate_dendrite_df(path_to_neuron)
# Out:
# /Users/AlexCionca/opt/miniconda3/envs/STD/lib/python3.7/site-packages/pandas/core/frame.py:9203: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Collection_x'} in the result is deprecated and will raise a MergeError in a future version.
#   validate=validate,
# Successfully converted data from 64 dendrites (30 features found).

# %%
my_dendrite_df.head()
# Out:
#              ID  Category  Depth  Level  Set 1  Dendrite Area  \
# 0  510000000001  Dendrite      0      1  Basal      39.077702
# 1  510000000004  Dendrite      1      1  Basal     100.997002
# 2  510000000009  Dendrite      3      2  Basal     492.992004
# 3  510000000021  Dendrite      4      3  Basal      82.556198
# 4  510000000023  Dendrite      5      4  Basal     167.626007
#
#    Dendrite Branch Depth  Dendrite Branch Level  Dendrite Branching Angle  \
# 0                      0                      1                   0.00000
# 1                      1                      1                   2.18238
# 2                      3                      2                   8.68663
# 3                      4                      3                   9.58429
# 4                      5                      4                   5.03014
#
#    Dendrite Branching Angle B  ...  Dendrite Position Y_y       Collection_x  \
# ...

# %%
dload.get_neuron_specific_features(path_to_neuron)
# Out:
# {'Filament BoundingBoxAA Length X': 571.7459716796875,
#  'Filament BoundingBoxAA Length Y': 487.239013671875,
#  'Filament BoundingBoxAA Length Z': 83.47730255126953,
#  'Filament BoundingBoxOO Length A': 83.8156967163086,
#  'Filament BoundingBoxOO Length B': 514.1090087890625,
#  'Filament BoundingBoxOO Length C': 599.2890014648438,
#  'Filament Dendrite Length (sum)': 5181.5498046875,
#  'Filament Distance from Origin': 1074.219970703125}
